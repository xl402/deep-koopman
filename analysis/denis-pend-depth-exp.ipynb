# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

sys.path.append("../model")
sys.path.append("../control")
from networks import *
from analysis_util import *
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Non-Linear Pendulum

# %%
model_names = ["d-depth-exp-1", "d-depth-exp-2", "d-depth-exp-3", "d-depth-exp-4"]
model_labels = [r"$d=4$", r"$d=5$", r"$d=6$", r"$d=7$"]
PATH = "../saved/logs/models/denis-depth-exp/pendulum"
x_true = np.load('../data/raw_data/pend_val.npy')

models, model_configs = load_models(DENIS, PATH, model_names)

# %%
n_shifts = model_configs[0]['n_shifts']
t_end = 100
results = plot_mse_mad(models, model_labels, x_true, n_shifts, t_end)
# Out:
# 100%|██████████| 4/4 [00:17<00:00,  4.38s/it]

# %%
for i in range(4):
    print(model_labels[i])
    _ = plot_trajectories(models[i], 50, x_true)
# Out:
# $d=4$
# $d=5$
# $d=6$
# $d=7$

# %% [markdown]
# ## Duffing Oscillator

# %%
model_names = ["d-depth-exp-1", "d-depth-exp-2", "d-depth-exp-3", "d-depth-exp-4"]
model_labels = [r"$d=4$", r"$d=5$", r"$d=6$", r"$d=7$"]
PATH = "../saved/logs/models/denis-depth-exp/duffing"
x_true = np.load('../data/raw_data/duffing_val.npy')

models, model_configs = load_models(DENIS, PATH, model_names)

# %%
n_shifts = model_configs[0]['n_shifts']
t_end = 100
results = plot_mse_mad(models, model_labels, x_true, n_shifts, t_end)
# Out:
# 100%|██████████| 4/4 [00:16<00:00,  4.14s/it]

# %%
for i in range(4):
    print(model_labels[i])
    _ = plot_trajectories(models[i], 50, x_true)
# Out:
# $d=4$
# $d=5$
# $d=6$
# $d=7$

# %%
##
